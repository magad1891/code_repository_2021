# %%
import requests

#----------------------------- system to promote employees

class Employee:
    def __init__(self, name, seniority):
        self.name = name
        self.seniority = seniority

        self.grade = 1

    def grade_up(self):
        """Increasing employee's grade by 1 """
        self.grade += 1

    def publish_grade(self):
        """Printing results of employee's promotion"""
        print(self.name, self.grade)

    def check_if_it_is_time_for_upgrade(self):
        pass


class Developer(Employee):
    def __init__(self, name, seniority):
        super().__init__(name, seniority)

    def check_if_it_is_time_for_upgrade_1(self):
        # ??? ?????? ???????????? ??????????? ??????? ?? 1
        # ???? ???????, ??? ??? ???????????? ???????? ????????????
        self.seniority += 1

        # ??????? ????????? ?????????? ?? ???????????
        if self.seniority % 5 == 0:
            self.grade_up()

        # ?????????? ???????????
        return self.publish_grade()


class Designer(Employee):
    def __init__(self, name, seniority):
        super().__init__(name, seniority)

    def check_if_it_is_time_for_upgrade_2(self, awards = 2):
        # ??? ?????? ???????????? ??????????? ??????? ?? 1
        # ???? ???????, ??? ??? ???????????? ???????? ????????????

        self.seniority += 1

        if self.seniority == 1:
            self.seniority += awards * 2
            print(f"Olga has seniority including {awards} awards", self.seniority)
        #print("self.seniority ", self.seniority, " awards ", awards)

        # ??????? ????????? ?????????? ?? ???????????
        if self.seniority % 7 == 0:
            self.grade_up()

        # ?????????? ???????????
        return self.publish_grade()


#alex = Developer('Alex', 0)
#for i in range(20):
#    print(alex.check_if_it_is_time_for_upgrade_1())

olga = Designer('Olga', 0)
for i in range(21):
    olga.check_if_it_is_time_for_upgrade_2()
# Out:
# Olga has seniority including 2 awards 5
# Olga 1
# Olga 1
# Olga 2
# Olga 2
# Olga 2
# Olga 2
# Olga 2
# Olga 2
# Olga 2
# Olga 3
# Olga 3
# Olga 3
# Olga 3
# Olga 3
# Olga 3
# Olga 3
# Olga 4
# Olga 4
# Olga 4
# Olga 4
# Olga 4
